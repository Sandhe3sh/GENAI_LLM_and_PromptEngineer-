# %%
from google.colab import userdata
api_key=userdata.get('GEMINI_API_KEY')

# %%
from google import genai

client = genai.Client(api_key=api_key)

interaction = client.interactions.create(
    model="gemini-3.5-flash",
    input="I am Sandheesh S"
)

# %%
interaction
# Out:
# Interaction(status='completed', model='gemini-3.5-flash', agent=None, id='v1_ChdtWGRZYXQzMUNlSGZqckVQeVp6MHVRWRIXbVhkWWF0MzFDZUhmanJFUHlaejB1UVk', created='2026-07-16T06:18:01Z', updated='2026-07-16T06:18:01Z', system_instruction=None, tools=None, usage=Usage(total_input_tokens=7, input_tokens_by_modality=[ModalityTokens(modality='text', tokens=7)], total_cached_tokens=0, cached_tokens_by_modality=None, total_output_tokens=21, output_tokens_by_modality=None, total_tool_use_tokens=0, tool_use_tokens_by_modality=None, total_thought_tokens=200, total_tokens=228, grounding_tool_count=None), response_modalities=None, response_mime_type=None, previous_interaction_id=None, environment_id=None, service_tier='standard', webhook_config=None, steps=[ThoughtStep(type='thought', signature='...', summary=None), ModelOutputStep(type='model_output', content=[TextContent(text="Hello Sandheesh S! It's nice to meet you. How can I help you today?", type='text', annotations=None)], error=None)], response_format=None, environment=None, generation_config=None, cached_content=None, agent_config=None, input=None, output_text="Hello Sandheesh S! It's nice to meet you. How can I help you today?", output_image=None, output_audio=None, output_video=None, object='interaction')

# %%
interaction2 = client.interactions.create(
    model="gemini-3.5-flash",
    input="Count the characters in my name",
    previous_interaction_id=interaction.id
)

# %%
interaction2
# Out:
# Interaction(status='completed', model='gemini-3.5-flash', agent=None, id='v1_ChdtWGRZYXQzMUNlSGZqckVQeVp6MHVRWRIXMkhkWWF2NmhJN0djLThZUHctamx5UVU', created='2026-07-16T06:19:04Z', updated='2026-07-16T06:19:04Z', system_instruction=None, tools=None, usage=Usage(total_input_tokens=236, input_tokens_by_modality=[ModalityTokens(modality='text', tokens=236)], total_cached_tokens=0, cached_tokens_by_modality=None, total_output_tokens=35, output_tokens_by_modality=None, total_tool_use_tokens=0, tool_use_tokens_by_modality=None, total_thought_tokens=371, total_tokens=642, grounding_tool_count=None), response_modalities=None, response_mime_type=None, previous_interaction_id=None, environment_id=None, service_tier='standard', webhook_config=None, steps=[ThoughtStep(type='thought', signature='...', summary=None), ModelOutputStep(type='model_output', content=[TextContent(text='Your name, **Sandheesh S**, has:\n\n* **11 characters** (including the space)\n* **10 characters** (excluding the space)', type='text', annotations=None)], error=None)], response_format=None, environment=None, generation_config=None, cached_content=None, agent_config=None, input=None, output_text='Your name, **Sandheesh S**, has:\n\n* **11 characters** (including the space)\n* **10 characters** (excluding the space)', output_image=None, output_audio=None, output_video=None, object='interaction')

# %%
from google.genai import types
from google import genai
client=genai.Client(api_key=api_key)
response=client.models.generate_content(
    model='gemini-3.5-flash',
    contents='Give me a Story',
    config=types.GenerateContentConfig(
        system_instruction='I say high, you say low',
        temperature=0.3,
    ),
)
print(response.text)
# Out:
# Once upon a time, in a world split in two, lived Zephyr and Terra.
#
# Zephyr lived in the **High**lands, perched on castles made of condensed cloud. He loved the screaming winds, the blinding sun, and the feeling of endless space.
#
# Terra lived in the **Low**lands, nestled in the deep, quiet caverns of the earth. She loved the steady hum of the tectonic plates, the warmth of the magma, and the glow of ancient crystals.
#
# They were best friends, but they could never visit each other. The air was too thin for Terra in the High, and the pressure was too heavy for Zephyr in the Low. Instead, they communicated through a magical brass speaking tube that stretched from the highest peak down into the deepest cavern.
#
# It became their favorite game.
#
# Zephyr would lean into the tube and shout, *"High!"*
# And a few seconds later, Terra’s voice would echo back from the depths, *"Low!"*
#
# They did this for years. High and low. Sky and stone.
#
# But one day, Zephyr grew tired of the endless blue. "I want to know what the earth feels like," he whispered into the tube.
#
# Terra, too, was tired of the shadows. "And I want to know what the sky feels like," she whispered back.
#
# So, they made a pact. They would meet in the middle.
#
# Zephyr began his descent, climbing down the jagged cliffs, leaving the thin, cold air behind. Terra began her ascent, climbing up the winding stone tunnels, leaving the heavy warmth of the deep.
#
# They met on the surface of the earth—a lush, green valley. It was a place where the grass was just *low* enough to carpet the dirt, and the trees grew just *high* enough to touch the breeze.
#
# Zephyr looked down at the soil beneath his feet, amazed by its solid strength. "It's so low," he whispered in awe.
#
# Terra looked up at the vast blue canopy above her, amazed by its endless reach. "It's so high," she breathed.
#
# They reached out and held hands, standing perfectly balanced in the middle.
